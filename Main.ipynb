# %%
################################################################################################################################
#                                                                                                                              #
#        practical-14                                                                                                          #
#        Our Problem  Defination is : Movie Recommended System  [ with the use of NLP (Countvectorized ,Cosine_Similarity) ]   #                                                                                                         
#                                                                                                                              #
#                                                                                                                              #
#    ''''Name: Arpita Makwana                                                                                                    # 
#        Enrollnment no: 216270307069'''' 
#  '''Name: Nirali Joshi'''
#       Enrollnment no: 216270307067'''                                                                                                                        #                                                                                                                      
#                                                                                                                              #
#                                                                                                                              #
#                                                                                                                              #
################################################################################################################################

# %%
#importing the necessay library.

import pandas as pd

# %%
#Read the CSV file.

movies=pd.read_csv('dataset.csv')

# %%
#show the first 10 column.

movies.head(10)
# Out:
#        id                        title                     genre  \
# 0     278     The Shawshank Redemption               Drama,Crime
# 1   19404  Dilwale Dulhania Le Jayenge      Comedy,Drama,Romance
# 2     238                The Godfather               Drama,Crime
# 3     424             Schindler's List         Drama,History,War
# 4     240       The Godfather: Part II               Drama,Crime
# 5  667257            Impossible Things              Family,Drama
# 6     129                Spirited Away  Animation,Family,Fantasy
# 7  730154               Your Eyes Tell             Romance,Drama
# 8  372754     Dou kyu sei – Classmates         Romance,Animation
# 9  372058                   Your Name.   Romance,Animation,Drama
#
#   original_language                                           overview  \
# 0                en  Framed in the 1940s for the double murder of h...
# 1                hi  Raj is a rich, carefree, happy-go-lucky second...
# ...

# %%
#movies.describe() provides statistical summary information for the numerical columns in the "movies"

movies.describe()
# Out:
#                   id    popularity  vote_average    vote_count
# count   10000.000000  10000.000000  10000.000000  10000.000000
# mean   161243.505000     34.697267      6.621150   1547.309400
# std    211422.046043    211.684175      0.766231   2648.295789
# min         5.000000      0.600000      4.600000    200.000000
# 25%     10127.750000      9.154750      6.100000    315.000000
# 50%     30002.500000     13.637500      6.600000    583.500000
# 75%    310133.500000     25.651250      7.200000   1460.000000
# max    934761.000000  10436.917000      8.700000  31917.000000

# %%
#movies.info() is used to retrieve information about the DataFrame "movies" in Python


movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 10000 non-null  int64
#  1   title              10000 non-null  object
#  2   genre              9997 non-null   object
#  3   original_language  10000 non-null  object
#  4   overview           9987 non-null   object
#  5   popularity         10000 non-null  float64
#  6   release_date       10000 non-null  object
#  7   vote_average       10000 non-null  float64
#  8   vote_count         10000 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 703.2+ KB

# %%
#this is check the any value is null or not.

movies.isnull().sum()
# Out:
# id                    0
# title                 0
# genre                 3
# original_language     0
# overview             13
# popularity            0
# release_date          0
# vote_average          0
# vote_count            0
# dtype: int64

# %% [markdown]
# Feature Selection Part

# %%
#show the columns.
movies.columns
# Out:
# Index(['id', 'title', 'genre', 'original_language', 'overview', 'popularity',
#        'release_date', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
#this is feature in movie recomended system  

movies=movies[['id', 'title', 'overview', 'genre']]

# %%
movies
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                overview  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
#we can threee feature merge in single column [tags].

movies['tags'] = movies['overview']+movies['genre']

# %%
movies
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                overview  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
#create a new data and removing the column overview and genre.

new_data  = movies.drop(columns=['overview', 'genre'])

# %%
new_data
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                    tags
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
#Start our main part:
#we can import the sklearn and train our model with the use of feature_extration and Countvectorizer.[Feature_extration
#is a part of the NLP].

from sklearn.feature_extraction.text import CountVectorizer

# %%
#limits the 10000 and stop count is used to removig some word like comman word 'a','an','in','the' .
cv=CountVectorizer(max_features=10000, stop_words='english')

# %%
cv
# Out:
# CountVectorizer(max_features=10000, stop_words='english')

# %%
# to transform the text data in the 'tags' column.

vector=cv.fit_transform(new_data['tags'].values.astype('U')).toarray()

# %%
#vector.shape provides the dimensions (number of rows and columns)of the numerical values.

vector.shape
# Out:
# (10000, 10000)

# %%
#import the cosine simiularity[it's also part of the Sklearn as well as Cosine_similarity]

from sklearn.metrics.pairwise import cosine_similarity

# %%
#find the similarity 

similarity=cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.05634362, 0.12888482, ..., 0.07559289, 0.11065667,
#         0.06388766],
#        [0.05634362, 1.        , 0.07624929, ..., 0.        , 0.03636965,
#         0.        ],
#        [0.12888482, 0.07624929, 1.        , ..., 0.02273314, 0.06655583,
#         0.08645856],
#        ...,
#        [0.07559289, 0.        , 0.02273314, ..., 1.        , 0.03253   ,
#         0.02817181],
#        [0.11065667, 0.03636965, 0.06655583, ..., 0.03253   , 1.        ,
#         0.0412393 ],
#        [0.06388766, 0.        , 0.08645856, ..., 0.02817181, 0.0412393 ,
#         1.        ]])

# %%
#test the similarity.

new_data[new_data['title']=="The Godfather"].index[0]
# Out:
# 2

# %%
#This code calculates the "distance" between a reference vector (index[2]) and all other vectors,
#sorts them in descending order by their values, and then prints the titles of the top 5 

distance = sorted(list(enumerate(similarity[2])), reverse=True, key=lambda vector:vector[1])
for i in distance[0:5]:
    print(new_data.iloc[i[0]].title)
# Out:
# The Godfather
# The Godfather: Part II
# Blood Ties
# Joker
# Bomb City

# %%
#find the index of movie dataset and match the input title.
def recommand(movies):
    index=new_data[new_data['title']==movies].index[0]
    # index= new_data.sample(frac=1).reset_index(drop=True)
    print(index)
    distance = sorted(list(enumerate(similarity[index+1])), reverse=True, key=lambda vector:vector[1])
    for i in distance[0:5]:
        print(new_data.iloc[i[0]].title)

# %%
recommand("Iron Man")

# %%
#The line "import pickle" is used to import the Python module "pickle," which provides a way to serialize
#and deserialize Python objects.

import pickle

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split

# Load the dataset
movies = pd.read_csv('dataset.csv')

# Select relevant columns
movies = movies[['id', 'title', 'overview', 'genre']]

# Combine 'overview' and 'genre' into 'tags'
movies['tags'] = movies['overview'] + movies['genre']

# Drop unnecessary columns
new_data = movies.drop(columns=['overview', 'genre'])

# Split the dataset into training and validation sets
train_data, validation_data = train_test_split(new_data, test_size=0.2, random_state=42)

# Vectorize the 'tags' column
cv = CountVectorizer(max_features=10000, stop_words='english')
vector = cv.fit_transform(train_data['tags'].values.astype('U')).toarray()

# Calculate cosine similarity
similarity = cosine_similarity(vector)

# Function to calculate precision at k
def precision_at_k(predictions, validation_set, k):
    precision_values = []
    for user_id, recommended_items in predictions.items():
        relevant_items = set(validation_set[validation_set['id'] == user_id]['title'])
        recommended_items = set(recommended_items[:k])
        precision = len(recommended_items.intersection(relevant_items)) / k
        precision_values.append(precision)
    return sum(precision_values) / len(precision_values)

# Function to recommend movies for a user
def recommend_movies_for_user(user_id):
    index = new_data[new_data['id'] == user_id].index[0]
    distance = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda vector: vector[1])
    recommendations = [new_data.iloc[i[0]].title for i in distance[1:6]]
    return recommendations

# Generate recommendations for each user in the validation set
user_predictions = {
    user_id: recommend_movies_for_user(user_id) for user_id in validation_data['id']
}

# Calculate precision at k
k = 5  # You can adjust k based on the number of recommendations you want to evaluate
precision = precision_at_k(user_predictions, validation_data, k)
print(f'Precision at {k}: {precision}')

# %%
#serialize the new data into a binary file named 'movies_list.pk' and wb is write into file 
pickle.dump(new_data, open('movies_list.pkl', 'wb'))

# %%
#This line of code uses the pickle.dump function to serialize and save the "similarity" data
#(likely a similarity matrix or some other data structure) into a binary file named 'similarity.pkl.' 

pickle.dump(similarity, open('similarity.pkl', 'wb'))

# %%
#This line of code uses pickle.load to deserialize and load the binary data from the 'movies_list.pkl' 
#file, which likely contains a serialized DataFrame (such as "new_data").

pickle.load(open('movies_list.pkl', 'rb'))
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                    tags
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...
